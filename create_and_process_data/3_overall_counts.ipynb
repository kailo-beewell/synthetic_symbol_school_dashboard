# %% [markdown]
# # Find overall counts of responses in each school
#
# This notebooks aims to find the overall count of pupils in the dataset for a given school and group, regardless of whether they answered a particular question.

# %% [markdown]
# ## Set-up
#
# ### Packages and file paths

# %%
# Import required packages
from dataclasses import dataclass
from kailo_beewell_dashboard.synthesise_aggregate import (
    aggregate_counts, results_by_site_and_group)
import numpy as np
import os
import pandas as pd

# %%
# File paths
@dataclass(frozen=True)
class Paths:
    '''Stores paths to data and files'''
    data = '../data/survey_data'
    synthetic_data = 'symbol_synthetic_data_raw.csv'
    overall_counts = 'symbol_school_overall_counts.csv'


paths = Paths()

# %% [markdown]
# ### Import raw data

# %%
data = pd.read_csv(os.path.join(paths.data, paths.synthetic_data))
data.head()
# Out:
#    symbol_family  symbol_home  symbol_friends  symbol_choice  symbol_things  \
# 0            2.0            2             1.0            1.0            3.0
# 1            NaN            1             1.0            2.0            2.0
# 2            NaN            1             2.0            2.0            2.0
# 3            NaN            2             3.0            NaN            2.0
# 4            3.0            1             2.0            2.0            2.0
#
#    symbol_health  symbol_future  symbol_school  symbol_free  symbol_life  ...  \
# 0              1            1.0            2.0          2.0          3.0  ...
# 1              3            2.0            NaN          2.0          1.0  ...
# 2              1            2.0            2.0          1.0          1.0  ...
# 3              1            2.0            1.0          2.0          3.0  ...
# 4              2            1.0            2.0          2.0          1.0  ...
#
#    symbol_school_lab  symbol_free_lab  symbol_life_lab  gender_lab  \
# 0                 Ok               Ok              Sad        Male
# 1                NaN               Ok            Happy      Female
# 2                 Ok            Happy            Happy      Female
# 3              Happy               Ok              Sad      Female
# 4                 Ok               Ok            Happy      Female
#
#    year_group_lab  fsm_lab  sen_lab    ethnicity_lab english_additional_lab  \
# 0         Year 11      FSM      SEN  Ethnic minority                    Yes
# 1         Year 10  Non-FSM  Non-SEN  Ethnic minority                    Yes
# 2         Year 11      FSM  Non-SEN    White British                    Yes
# 3         Year 11  Non-FSM      SEN    White British                    Yes
# 4         Year 10      FSM  Non-SEN    White British                     No
#
#   school_lab
# 0   School B
# 1   School A
# 2   School B
# 3   School B
# 4   School B
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Create counts dataframe

# %%
# Make version for when there are no pupils
no_pupils = aggregate_counts(data)
no_pupils['count'] = 0
no_pupils
# Out:
#    count
# 0      0

# %%
# Find counts by school and pupil group
size = results_by_site_and_group(
    data=data, agg_func=aggregate_counts, no_pupils=no_pupils,
    group_type='symbol')

# Hide counts where n<10
size.loc[size['count'] < 10, 'count'] = np.nan

# Preview result
size.sort_values(by=['year_group_lab', 'gender_lab',
                     'fsm_lab', 'school_lab'])
# Out:
#    count school_lab year_group_lab gender_lab  fsm_lab
# 0   30.0   School A            All        All      All
# 0   30.0   School B            All        All      All
# 0   17.0   School A            All        All      FSM
# 0   16.0   School B            All        All      FSM
# 0   13.0   School A            All        All  Non-FSM
# 0   14.0   School B            All        All  Non-FSM
# 0    NaN   School A            All        Boy      All
# 0    NaN   School B            All        Boy      All
# 0    NaN   School A            All       Girl      All
# 0    NaN   School B            All       Girl      All
# 0    NaN   School A        Year 10        All      All
# 0    NaN   School B        Year 10        All      All
# 0    NaN   School A        Year 11        All      All
# 0    NaN   School B        Year 11        All      All
# 0    NaN   School A         Year 7        All      All
# 0    NaN   School B         Year 7        All      All
# 0   13.0   School A         Year 8        All      All
# 0    NaN   School B         Year 8        All      All
# 0    NaN   School A         Year 9        All      All
# 0   11.0   School B         Year 9        All      All

# %%
# Show the data types and presence of null
types = size.dtypes
null = size.isnull().any()
pd.DataFrame([types, null]).T
# Out:
#                       0      1
# count           float64   True
# school_lab       object  False
# year_group_lab   object  False
# gender_lab       object  False
# fsm_lab          object  False

# %% [markdown]
# ## Save results

# %%
size.to_csv(os.path.join(paths.data, paths.overall_counts),
            index=False, na_rep='NULL')
